# %% [markdown]
# # I Одно измерение по пространству (если нет частных производных, то  это просто набор одинаковых уравнений с разными начальными значениями)
#
#
#
# ## Линейные уравнения:
#
#
# ### Уравнение неустойчивого фокуса
#
# Дана система линейных уравнений:
#
# \begin{array}{l} U'=2*U+V, \\ V'=-5*U.  \end{array}
#
# Ссылка: [prosto_fazportret](tests/prosto_fazportret.ipynb)
#
# Результат: Совпадает с действительностью, показывает раскручивающийся фокус по часовой стрелке.
#
# ### Система где одно из собственных значений равно 0
#
# Дана система линейных уравнений:
#
# \begin{array}{l} U'=-2*U+V, \\ V'=6*U-3*V.  \end{array}
#
# Ссылка: [prosto_fazportret1](tests/prosto_fazportret1.ipynb)
#
# Результат: Совпадает с действительностью, показывает траекторию ввиед отрезка конец которой приближается к прямой состояний равновесия.
#
# ### Система с медленно раскручивающимся фокусом
#
# Дана система уравнений:
#
# \begin{array}{l} U'=U*(U^2+V^2)-V, \\ V'=V*(U^2+V^2)+U.  \end{array}
#
# Ссылка: [prosto_fazportret2](tests/prosto_fazportret2.ipynb)
#
# Результат: Совпадает с действительностью.
#
#
# ### Система с тремя состониями равновесия
#
# Дана система уравнений:
#
# \begin{array}{l} U'=U*V-4, \\ V'=(U-4)*(V-U).  \end{array}
#
# Ссылка: [prosto_fazportret3](tests/prosto_fazportret3.ipynb)
#
# Результат: Совпадает с действительностью, начальное вращение траектории описывает движение от неустойчивого фокуса к устойчивому, заметна разница между решением трейсера и решением библиотечного метода.
#
#
# ### Система описывающая хищник-жертва (первый вариант)
#
# Дана система уравнений:
#
# \begin{array}{l} U'=2*U-U*V, \\ V'=-2*V+U*V.  \end{array}
#
# Ссылка: [prosto_fazportret4](tests/prosto_fazportret4.ipynb)
#
# Результат: достаточно достоверно описывает решение, разница между бибилотечным и решением tracer есть библиотечный быстрее отбегает (в действительности аналитическое решение представляет из себя цикл), очень хорошо показана разность решений.
#
#
#
# ### Система имеющая чисто мнимые корни
#
# Дана система уравнений:
#
# \begin{array}{l} U'=V, \\ V'=U.  \end{array}
#
# Ссылка: [trigonometric_test](tests/trigonometric_test.ipynb)
#
# Результат: Достаточно неплохо описывает решение, аналитичское решение данной системы является цикл, решение которое представляет tracer лучше чем библиотечный метод.
#
#
# ## Уравнения с предельным циклом:
#
#
# ### Система имеющая кубическую нелинейность
#
# Дана система уравнений:
#
# \begin{array}{l} U'=(V-U*U*U+U)*20, \\ V'=-U.  \end{array}
#
# Ссылка: [cycle_nelin_test](tests/cycle_nelin_test.ipynb)
#
# Результат: достаточно достоверно описывает решение, показывает предельный цикл, хочется отметить что если поставить маленькое количество точек сохранения по времени то первые линии до приближения к циклу может рисовать в виде ломаных.
#
#
#
#
# ### Система имеющая кубическую нелинейность
#
# Дана система уравнений:
#
# \begin{array}{l} U'=2*U+V-U*U*U*5, \\ V'=-5*U.  \end{array}
#
# Ссылка: [cycle_nelin_test1](tests/cycle_nelin_test1.ipynb)
#
# Результат: достаточно достоверно описывает решение, показывает предельный цикл, хочется отметить что если поставить маленькое количество точек сохранения по времени то первые линии до приближения к циклу может рисовать в виде ломаных.
#
#
# ### Система с предельным устойчивым циклом
#
# Дана система уравнений:
#
# \begin{array}{l} U'=U*(U^2+V^2)-V+U, \\ V'=V*(U^2+V^2)+U+V.  \end{array}
#
# Ссылка: [cycle_nelin_test2](tests/cycle_nelin_test2.ipynb)
#
# Результат: Совпадает с действительностью.
#
#
#
#
#
#
# ## Уравнения с частными производными (теплопроводность):
#
# ### Уравнение теплопроводности 1
#
# Дано однородное уравнение теплопроводности с условием Дирихле:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}, \\ U(x,0)=\sin^3(x), \\ U(0,t)=U(\pi,t)=0.  \end{array}
#
# Ссылка: [teplo1](tests/teplo1.ipynb)
#
# Результат: достаточно достоверно описывает решение, имеет неплохое сравнение с относительным решением.
#
# ### Уравнение теплопроводности 2
#
# Дано однородное уравнение теплопроводности с условием Дирихле:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}, \\ U(x,0)=x*(1-x), \\ U(0,t)=U(1,t)=0.  \end{array}
#
# Ссылка: [teplo2](tests/teplo2.ipynb)
#
# Результат: достаточно достоверно описывает решение, имеет неплохое сравнение с относительным решением.
#
# ### Уравнение теплопроводности 3
#
# Дано однородное уравнение теплопроводности с условием Неймана:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}, \\ U(x,0)=\sin^3(x), \\ U(0,t)=U(\pi,t)=0.  \end{array}
#
# Ссылка: [teplo3](tests/teplo3.ipynb)
#
# Результат: достаточно достоверно описывает решение, имеет неплохое сравнение с относительным решением.
#
#
#
# ### Уравнение теплопроводности 4
#
# Дано однородное уравнение теплопроводности с условием Неймана:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}, \\ U(x,0)=\sin^3(x), \\ U(0,t)=\sin(x), U(\pi,t)=0.  \end{array}
#
# Ссылка: [teplo4](tests/teplo4.ipynb)
#
# Результат: показывает решение, которое хотелось увидть, а имеео волну, качественно совпадает с ожиданием.
#
#
# ### Уравнение теплопроводности 5
#
# Дано однородное уравнение теплопроводности с условием Неймана:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}, \\ U(x,0)=\sin^3(x), \\ U(0,t)=1, U(\pi,t)=0.  \end{array}
#
# Ссылка: [teplo5](tests/teplo5.ipynb)
#
# Результат: Результат похожь на правду, в задлаче описывается нагрев одного из краев постоянной температурой.
#
#
#
#
#
#
# ### Уравнение теплопроводности 6
#
# Дано однородное уравнение теплопроводности с условием Неймана:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}, \\ U(x,0)=0, \\ U(0,t)=10.0*\sin(3.0*t), U(\pi,t)=-10.0*\sin(3.0*t).  \end{array}
#
# Ссылка: [teplo6](tests/teplo6.ipynb)
#
# Результат: Результат похожь на правду, в задлаче описывается нагрев и охлаждение с разных сторон как взаимогаснущие силы, тест был придуман чтобы посмореть не двигается ли точка на середине отрезка, по скольку она должна быть неподвижной.
#
#
#
# ### Уравнение теплопроводности 7
#
# Дано однородное уравнение теплопроводности с условием Дирихле:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}, \\ U(x,0)=0, \\ U(0,t)=10.0*\sin(3.0*t), U(\pi,t)=-10.0*\sin(3.0*t).  \end{array}
#
# Ссылка: [teplo7](tests/teplo7.ipynb)
#
# Результат: Результат похожь на правду, в задлаче описывается нагрев и охлаждение с разных сторон как взаимогаснущие силы, тест был придуман чтобы посмореть не двигается ли точка на середине отрезка, по скольку она должна быть неподвижной.
#
#
# ## <span style="color:red">Уравнение адвекции:</span>
#
#
# ### Уравнение Адвекции1
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=-\frac{\partial  U}{\partial x}, \\ U(x,0)=10-x.  \end{array}
#
# Ссылка: [advek1](tests/advek1.ipynb)
#
# Результат: не правильно рисут.
#
#
#
# ## <span style="color:red">Уравнение теплопроводности неоднородное:</span>
#
# ### Не правильно работает явный пример уравнение  неоднородное теплопроводности 3
#
# ### Уравнение неоднородное теплопроводности 1
#
# Дано неоднородное уравнение теплопроводности:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}+e^{-9t}\sin(3x), \\ U(x,0)=\sin(x), \\ U(0,t)=U(\pi,t)=0.  \end{array}
#
# Ссылка: [neodteplo1](tests/neodteplo1.ipynb)
#
#
# ### Уравнение неоднородное теплопроводности 2
#
# Дано неоднородное уравнение теплопроводности:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}+t\sin(3x)^3, \\ U(x,0)=x^2-x, \\ U(0,t)=U(\pi,t)=0.  \end{array}
#
# Ссылка: [neodteplo2](tests/neodteplo2.ipynb)
#
#
# ### Уравнение неоднородное теплопроводности 3
#
# Дано неоднородное уравнение теплопроводности:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}-100e^{-t}\sin(x), \\ U(x,0)=\sin(x), \\ U(0,t)=U(\pi,t)=0.  \end{array}
#
# Ссылка: [neodteplo3](tests/neodteplo3.ipynb)
#
#
# ### Уравнение неоднородное теплопроводности 4
#
# Дано неоднородное уравнение теплопроводности:
#
# \begin{array}{l} \displaystyle \frac{\partial U}{\partial t}=\frac{\partial ^2 U}{\partial x^2}+\sin(x), \\ U(x,0)=\sin(x), \\ U(0,t)=U(\pi,t)=0.  \end{array}
#
# Ссылка: [neodteplo4](tests/neodteplo4.ipynb)
#
#
#
#
#
# ## Уравнение с запаздыванием
#
# ### <span style="color:red"> Есть проблема что он не распознает символ запаздывания то тесть U(t-h) он не понимает а вот U(t-1.0) видит и разбирает, и по всей видимости знак деления он понимает как знак умножения!!!!!!!!!!</span>
#
# ### Уравнение Хатчинсона популяционная задача
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle U'= a*(b-U(t-1))*U, \\ U(t)=1,\, при\,t<0,\, a=1,\, b=2.  \end{array}
#
# Ссылка: [hutchinson_test](tests/hutchinson_test.ipynb)
#
# Результат: Показано качественное решение правильно, с решением библиотечного метода есть разница, но не большая.
#
#
#
# ### Уравнение Хатчинсона популяционная задача  с устойчивым состоянием равновесия
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle U'= a*(1-U(t-1))*U, \\ U(t)=1,\, при\,t<0,\, a=1.  \end{array}
#
# Ссылка: [ur_zap_test1](tests/ur_zap_test1.ipynb)
#
# Результат: Показывает качественно достоверную информацию.
#
#
#
# ### Уравнение Хатчинсона популяционная задача  с миграцией
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle U'= a*(1-U(t-1))*U+0.01, \\ U(t)=0.5,\, при\,t<0,\, a=4.  \end{array}
#
# Ссылка: [ur_zap_test2](tests/ur_zap_test2.ipynb)
#
# Результат: Показывает качественно достоверную информацию, есть сравнение с решением библиотечного метода.
#
#
#
# ### Уравнение Хатчинсона популяционная задача  с большим параметром
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle U'= a*(1-U(t-1))*U, \\ U(t)=0.5,\, при\,t<0,\, a=4.  \end{array}
#
# Ссылка: [ur_zap_test3](tests/ur_zap_test3.ipynb)
#
# Результат: Показывает качественно достоверную информацию, то есть такие всплески и долгие паузы правдивы в аналитическом решении.
#
#
#
#
# ### Уравнение популяции насекомых
#
# Дано уравнение:
#
# \begin{array}{l} \displaystyle U'= a*(1-b*(1-U(t-t1))-U(t-t2))*U, \\ U(t)=0.5,\, при\,t<0,\, a=3,\, b=0,9,\, t1=1,\, t2=0,3.  \end{array}
#
# Ссылка: [ur_zap_test4](tests/ur_zap_test4.ipynb)
#
# Результат: Показывает качественно достоверную информацию поведение решение схоже с аналитическим, в то время как библиотечный метод рисует не правильно.
#
#
# ### Простейшая модель экономики оборота денег и товара
#
# Дано уравнение:
#
# \begin{array}{l} \displaystyle U'= a*(V-U), \\ V'= b*(U-V(t-1)) \\ U(t)=100,\,V(t)=20,\, при\,t<0, \\ a=2,\, b=1.  \end{array}
#
# Ссылка: [ur_zap_test5](tests/ur_zap_test5.ipynb)
#
# Результат: Показывает качественно достоверную информацию поведение решение схоже с аналитическим, то есть выходит на состояние равновесия при правильном подборе параметров, то есть $b<=1$.
#
#
#
#
# ### <span style="color:yellow">Упрощенная модель ядерного реактора</span>
#
# Дано уравнение:
#
# \begin{array}{l} \displaystyle U'= -(a+b)*U+a*U*U+b*U*V(t-1), \\ V'= U-V \\ U(t)=0.5,\,V(t)=1,\, при\,t<0, \\ a=10,\, b=10.  \end{array}
#
# Ссылка: [ur_zap_test6](tests/ur_zap_test6.ipynb)
#
# Результат: Оно не посчиталось при запуске коэф а=10 и b=10, по аналитическому решению ожидалось что траектория запуска придет к состоянию равновесия, тест требует более тщательного рассмотрения.
#
#
#
# ### <span style="color:red">Уравнение конкуренции</span>
#
# Дано уравнение конкуренции:
#
# \begin{array}{l} \displaystyle U'= \frac{r}{(1+a)}*(1+a*(1-\frac{V}{kz})-\frac{U(t-h)}{k})*U, \\ \displaystyle V'= \frac{rz}{(1+az)}*(1+az*(1-\frac{U}{k})-\frac{V(t-hz)}{kz})*V \\ U(t)=24,\,V(t)=35,\, при\,t<0, \\
# r=3,\,
#                 a=0.7,\,
#                 k= 100,\,
#                 h= 0.5,\,
#                 rz= 2,\,
#                 az= 0.8,\,
#                 kz= 200,\,
#                 hz= 0.6.  \end{array}
#
# Ссылка: [ur_zap_test7](tests/ur_zap_test7.ipynb)
#
# Результат: не правильно решает задачу в задаче описана система конкуренции причем уравнения популяций без нее имеют состояние равновесия, то есть при запуске с любой точки эта система должна выставить оба вида к своему состоянию равновесия чего не происходит при решении трейсера, библиотечный метод решает эту задачу правильно. <span style="color:red"> В уравнении используется много параметров штук 8 и видимо для трейсера это проблема, если например параметр имеет имя более одного символа то он не распознает строку, если написать 8 параметров как вроде бы надо и инициализацию их то он не будет решать задачу и это проблема мне пришлось вбить все параметрами чисто в уравнение руками цифрами</span>
#
#
#
#
# ### <span style="color:red">Уравнение Хатчинсона где есть деление </span>
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle U'= \frac{r}{(1.0+a)}*(1-U(t-1.0)*k)*U, \\  \\ U(t)=24,\, при\,t<0, \\
# r=3,\,
#                 a=2,\,
#                 k= 0.01.  \end{array}
#
# Ссылка: [ur_zap_test8](tests/ur_zap_test8.ipynb)
#
# Результат: Он не видит разницы между знаком деления и умножения то есть домножить на 0.3333333 или поделить на 3 для него это разные вещи вместо того чтобы поделить на 3 он умножит на 3 и получается что вместо устойчивого хатчинсона мы получаем Хатчинсона с огромным парметром.
#
# ### <span style="color:red">Уравнение Хатчинсона просмотр работы с параметрами </span>
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle U'= r*(1+a*(1-V*kz)-U(t-h)*k)*U, \\ \displaystyle V'= rz*(1+az*(1-U*k)-V(t-hz)*kz)*V \\ U(t)=24,\,V(t)=35,\, при\,t<0, \\
# r=1.7647,\,
#                 a=0.7,\,
#                 k= 0.01,\,
#                 h= 0.5,\,
#                 rz= 0.8111,\,
#                 az= 0.8,\,
#                 kz= 0.005,\,
#                 hz= 0.6.  \end{array}
# Ссылка: [ur_zap_test9](tests/ur_zap_test9.ipynb)
#
# Результат: Сколько бы параметров не внедрять он будет распознавать видеть из всего списка только первые два по крайней мере перебирая все варианты подстановки он видет толко если используются первые два, иначе он выдает что результат собирается и прекращает работу. Так же возникает вопрос о правильности решения задачи потому что с библиотечным методом решение трейсера очень сильно отличается
#
#
# # II проверка других численных методов
# Сейчас все проверялось для "SolverIdx": 0 (метод Эйлера)
# Надо также проверять для 1 (Рунге-Кутта 4) и 2 (Дорман-Принс 8) с автоматическим подбором шага)
# Для этого взять задачу из ОДУ и ДДУ, которая нормально считалась Эйлером и посчитать этими двумя тоже
#
#
#
# ## Метод Рунге Кута 4 порядок:
#
# ### Система с медленно раскручивающимся фокусом
#
# Дана система уравнений:
#
# \begin{array}{l} U'=U*(U^2+V^2)-V, \\ V'=V*(U^2+V^2)+U.  \end{array}
#
# Ссылка: [prosto_fazportret5](tests/prosto_fazportret5.ipynb)
#
# Результат: Совпадает с действительностью, рисует похожее изображение как при методе Эйлера.
#
#
# ### Система с тремя состониями равновесия
#
# Дана система уравнений:
#
# \begin{array}{l} U'=U*V-4, \\ V'=(U-4)*(V-U).  \end{array}
#
# Ссылка: [prosto_fazportret6](tests/prosto_fazportret6.ipynb)
#
# Результат: Совпадает с действительностью.
#
#
#
# ### Система с предельным устойчивым циклом
#
# Дана система уравнений:
#
# \begin{array}{l} U'=U*(U^2+V^2)-V+U, \\ V'=V*(U^2+V^2)+U+V.  \end{array}
#
# Ссылка: [cycle_nelin_test3](tests/cycle_nelin_test3.ipynb)
#
# Результат: Совпадает с действительностью.
#
#
# ### Уравнение Хатчинсона популяционная задача
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle U'= a*(b-U(t-1))*U, \\ U(t)=1,\, при\,t<0,\, a=1,\, b=2.  \end{array}
#
# Ссылка: [hutchinson_test1](tests/hutchinson_test1.ipynb)
#
# Результат: Показано качественное решение правильно, с решением библиотечного метода разница стала меньше.
#
#
# ### Уравнение Хатчинсона популяционная задача  с устойчивым состоянием равновесия
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle U'= a*(1-U(t-1))*U, \\ U(t)=1,\, при\,t<0,\, a=1.  \end{array}
#
# Ссылка: [hutchinson_test3](tests/hutchinson_test3.ipynb)
#
# Результат: Показывает качественно достоверную информацию.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ## Дорман-Принс 8
#
#
# ### Система с медленно раскручивающимся фокусом
#
# Дана система уравнений:
#
# \begin{array}{l} U'=U*(U^2+V^2)-V, \\ V'=V*(U^2+V^2)+U.  \end{array}
#
# Ссылка: [prosto_fazportret7](tests/prosto_fazportret7.ipynb)
#
# Результат: Cовпадает с действительностью, при точности $10^{-6}$ он создал 51 точку, рисует хуже чем библиотечный метод (он быстрее отходит.
#
#
#
#
# ### Система с тремя состониями равновесия
#
# Дана система уравнений:
#
# \begin{array}{l} U'=U*V-4, \\ V'=(U-4)*(V-U).  \end{array}
#
# Ссылка: [prosto_fazportret8](tests/prosto_fazportret8.ipynb)
#
# Результат: Совпадает с действительностью, рисует почти так же как рисует бибилотечный метод при построении задействовал 223 точки на 10 секунд.
#
#
#
# ### Система с предельным устойчивым циклом
#
# Дана система уравнений:
#
# \begin{array}{l} U'=U*(U^2+V^2)-V+U, \\ V'=V*(U^2+V^2)+U+V.  \end{array}
#
# Ссылка: [cycle_nelin_test4](tests/cycle_nelin_test4.ipynb)
#
# Результат: Совпадает с действительностью, при построении решения делает 401 точку.
#
#
#
# ### <span style="color:red">Уравнение Хатчинсона популяционная задача</span>
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle U'= a*(b-U(t-1))*U, \\ U(t)=1,\, при\,t<0,\, a=1,\, b=2.  \end{array}
#
# Ссылка: [hutchinson_test2](tests/hutchinson_test2.ipynb)
#
# Результат: Все плохо не имеет ничего общего с действительностью уходит в плюс бесконечность, далает странный шаг и в конце показывает огроменное число.
#
#
# ### <span style="color:red">Уравнение Хатчинсона популяционная задача  с устойчивым состоянием равновесия</span>
#
# Дано уравнение Хатчинсона:
#
# \begin{array}{l} \displaystyle U'= a*(1-U(t-1))*U, \\ U(t)=1,\, при\,t<0,\, a=1.  \end{array}
#
# Ссылка: [hutchinson_test4](tests/hutchinson_test4.ipynb)
#
# Результат: Даже не досчитал он завис чтобы я не пытался делать.
#
#
# # III Два измерения по пространству
