# %% [markdown]
# I Одно измерение по пространству (если нет частных производных, то  это просто набор одинаковых уравнений с разными начальными значениями)
#
#
# \large
# Линейное уравнение:
#
# \normalsize
#
#
# \{ \begin{array}{l}\varepsilon \dot{x}+x+\delta y=\beta_{1}F\left(x(t-\tau)\right), \\ \dot{y}=x.  \end{array}
# (Уравнение неустойчивого фокуса)
# Уравнение спирали с раскручиванием по часовой стрелки с начальными условиями очень близкими к состоянию равновесия.
# Ссылка: https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/prosto_fazportret.ipynb
#
# Результат: показал правильный рисунок.
#
# Система линейных уравнений у которого одно из собственных значений равно 0.
# Ссылка: https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/prosto_fazportret1.ipynb
#
# Результат: выполнил правильно от начальных условий построил траекторию которая стремится к целой прямой состояний равновесий.
#
# Нелинейная система по идее с двумя циклами.
# Ссылка: https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/prosto_fazportret2.ipynb
#
# Результат: Отрисовал часть цикла, на рисунке видно, что решение трейсера и библиотечного отличаются.
#
# Нелинейная система с тремя состояниями равновесия (седло фокус устойчивый и не уст)
# Ссылка: https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/prosto_fazportret3.ipynb
#
# Результат: Очень заметна разница между отрисовкой библиотечного метода и трейсера.
#
# Уравнение хищник жертва одно из первых его видов (без запаздывания)
# Ссылка:https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/prosto_fazportret4.ipynb
#
# Результат: Библиотечное решение показывает хуже результат чем трейсер, оба они конечно не показывают точного решения так как должен быть отрисованы циклы, но бибилотечное гораздо быстрее показывает раскручивающуюся спираль.
#
# Уравнение с предельным циклом
#
# Уравнение с кубической нелинейностью и устойчивым циклом 1
# Ссылка: https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/cycle_nelin_test.ipynb
#
# Результат: достаточно хорошо показывает результат схожий с аналитическим.
#
# Уравнение с кубической нелинейностью и устойчивым циклом 2
# Ссылка: https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/cycle_nelin_test1.ipynb
#
# Результат: Тоже достаточно хорошо показывает решение, правда при маленьком количестве точек или недостаточном точек созранения становится видно вместо гладкой кривой ломаную.
#
#
#
#
# Уравнение в частных производных типа теплопроводность (просто диффузия)
#
# Уравнение теплопроводности с начальными условиями $sin(x)^3$ с краями в точках 0 и $\pi$.
# Ссылка: https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/teplo1.ipynb
#
# Уравнение теплопроводности:
# $U'(t,x)=\frac{dU^2}{dx^2}$
#
# Ссылка: https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/teplo2.ipynb
#
#
# Уравнение теплопроводности с начальными условиями $sin(x)^3$ с краями в точках 0 и $\pi$.  (пришлось создать копию чтобы запускать отдельно)
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/teplo1/hutchinson_test.ipynb
#
# Уравнение теплопроводности с начальными условиями $sin(x)^3$ с краями в точках 0 и $pi$ и в них нули.
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/teplo4/hutchinson_test.ipynb
#
# Уравнение теплопроводности простой тест с одной стороны прирост с другой ничего
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/teplo5/hutchinson_test.ipynb
#
#
# Уравнение теплопроводности с усилием на края (на них меняется температура одинаковыми уравнениями но разных знаков) чтобы увидеть не двигается точка по середине отрезка(ее не должно было смещать) все произошло хорошо. Описано при условии неймана
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/teplo6/hutchinson_test.ipynb
#
#
#
# Уравнение теплопроводности с усилием на края (на них меняется температура одинаковыми уравнениями но разных знаков) чтобы увидеть не двигается точка по середине отрезка(ее не должно было смещать) все произошло хорошо. Описано при условии Дирихле
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/teplo7/hutchinson_test.ipynb
#
#
# Неоднородное уравнение теплопроводнсти
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/neodteplo1/hutchinson_test.ipynb
# Есть точное решение аналитическое и решение которое выдает трайсер количество точек для шагов по t взял много 10^6, разница между точным решением и решением которое выдает трейсер в начале делает скачек потом падение и меееедленно ползет вверх. Скорее всего этот скачек идет потому что я не попадаю в узлы сетки при решении методом точного и возможно из-за этого возникает.
# уравнение адвекции
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/advek1/hutchinson_test.ipynb
# Не работает, вроде все правильно вбил но не выдает результат
# Нужно делать разные имена у разных граничных условий, а то препроцессор их теряет, и вместо двух осталось одно.
# При построении делает что то не то по идее там должна была быть прямая 10-(х-t) (Это аналитическое решение уравнения) и t изменяется от 0 до 10 то есть выглядит как прямая движущаяся слева направа при отрисовке он берет какие то другие части с краев и тащет их.
#
#
#
# Уравнение в частных производных типа реакция-диффузия
# Уравнение с запаздыванием без частных производных
# Не работает начальная функция, зависящая от t
# Уравнение хатчинсона с малым параметром, то есть стремление вида к балансу и состоянию равновесия
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/ur_zap_test1/hutchinson_test.ipynb
#
#
# Уравнение хатчинсона с большим параметром вид очень сильно плодятся а потом почти вымирают
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/ur_zap_test3/hutchinson_test.ipynb
# При тестировании и трейсер и библиотечный метод показали не верное решение библиотечный вообще вылетает на минус бесконечность а метод трейсера хоть и показывает первый всплеск популяции, но потом после сверхпадения не выходит из ямы численности.
# Уравнение Хатчинсона с большим параметром и миграцией (чтобы не было так сильно вымирание, но оно все равно остается по теоретическому решению)
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/ur_zap_test2/hutchinson_test.ipynb
# И тот и тот метод качественно показывают верный результат (то есть периодичность решения всплески резкие падения)
# Уравнение численности насекомых
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/ur_zap_test4/hutchinson_test.ipynb
#
# Результат почему то не работает если поменять dx с 0.01 хотя бы на 0.1
# -- это проблема расчета доступной памяти, где-то ошибка в ядре, сейчас приходится указывать меньший доступный объем в файле проекта
# очень медленно собирается библиотечный метод показывает правдивую версию метод трейсера пока не знаю так как он собирается уже порядка 2 часов.
# При запуске трейсера если оставить его на ночь (порядка 8 часов сборки при таких условиях) он выдает ответ более правильный чем библиотечный, потому что библиотечный выдает количество периодических скачков с большей частотой в 2 раза приблизительно, в то время как трейсер выйдя на периодические скачки начинает их выдавать с частотой суммы запаздываний.
# Простейшая экономическая модель оборота денег и товаров
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/ur_zap_test5/hutchinson_test.ipynb
#
# Результат близок к действительности
# Модель ядерного реактора (технически это огромный котел который имеет теплоемкость и мощность, теоретически рассматривал только как область двух параметров такие чтобы было устойчивое решение)
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/ur_zap_test6/hutchinson_test.ipynb
#
#
# Модель конкуренция с двумя разными запаздываниями
# https://cudahub.accelcomp.org/user/hpc/notebooks/cudahub/tracer/hybriddomain/tests/ur_zap_test7/hutchinson_test.ipynb
# Выглядит ошибкой потому что не правильно показывает результат (синяя и оранжевая линия)
# Зеленая и красная показывают уравнение библиотечным методом и это больше похоже на правду.
# Уравнение с запаздыванием и частными производными
#
#
# II проверка других численных методов
# Сейчас все проверялось для "SolverIdx": 0 (метод Эйлера)
# Надо также проверять для 1 (Рунге-Кутта 4) и 2 (Дорман-Принс 8) с автоматическим подбором шага)
# Для этого взять задачу из ОДУ и ДДУ, которая нормально считалась Эйлером и посчитать этими двумя тоже
#
# III Два измерения по пространству
